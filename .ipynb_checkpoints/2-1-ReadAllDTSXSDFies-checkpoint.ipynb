# %%
# Read the general DTS and save the taxonomy schema to PostgreSQL
from hibachiPostgreSQL import ReadAllGeneralDTSPathesInPostgre # For getting file general DTS pathes
from hibachixbrl import HibachiXmlElement, HibachiETtree
import pandas as pd
import sys
import os

# %%
# Get all the general DTS file pathes saved in PostgreSQL 
df_DTSPathes = ReadAllGeneralDTSPathesInPostgre.generalDTSPathes()
# Out:
# Connecting to the PostgreSQL database...
# Connection is closed.

# %%
def readXSDinGeneralDTS(df_generalDTS):
    ''' Get all the TaxonomySchema, Linkbase, FootnoteLink, Roletype classes in .xsd file.'''

    for CurrentPathName in df_generalDTS['filepath']:
        #Get the extention of the current file
        CurrentFileName = os.path.split(CurrentPathName)[1]
        CurrentFileExtension = os.path.splitext(CurrentPathName)[1] 
        if CurrentFileExtension == '.xsd':
            
            # Dataframes for TaxonomySchema, Linkbase, RoleTypes
            df_TaxonomySchema = pd.DataFrame(columns=['filepath','TaxonomySchemaObj'])
            df_Linkbases      = pd.DataFrame(columns=['filepath','linkbaseObj'])
            df_RoleTypes      = pd.DataFrame(columns=['filepath','roletypeObj'])    
        
            try:
                root_ElementTree = HibachiETtree.etree_parse_remove_NS(CurrentPathName)
                if root_ElementTree != None:
                    
                    # List of tags for taxonomy schema, linkbase and roleType/Refs
                    schema_tags = ['import','include','schemaRef','linkbaseRef','roleRef', 'arcroleRef']
                    linkbase_tags = ['linkbase','schema']
                    search_tags = schema_tags + linkbase_tags
                    
                    # Search elements with the tags listed above and corresponding create instances
                    for empty_Var, search_tagName in enumerate(search_tags):
                        for schema_ElementTree in root_ElementTree.iter(search_tagName):
                            # Taxonomy Schema
                            if search_tagName in schema_tags:
                                #print(search_tagName)
                                df_TaxonomySchema = df_TaxonomySchema.append(\
                                    {'filepath':CurrentPathName,\
                                     'TaxonomySchemaObj':HibachiXmlElement.TaxonomySchema(CurrentFileName, schema_ElementTree)}\
                                    ,ignore_index=True
                                )
                                
                            # 5.1.2 <linkbase>
                            elif search_tagName == 'linkbase':
                                df_Linkbases = df_Linkbases.append(\
                                    {'filepath':CurrentPathName,\
                                     'linkbaseObj':HibachiXmlElement.Linkbase(CurrentFileName, schema_ElementTree)}\
                                    ,ignore_index=True
                                )
                                
                            # 5.1.3 <roleType>, 5.1.4 <arcroleType>
#                             5.1.3 Defining custom role types - the <roleType> element
#                             The <roleType> element MUST be located among the set of nodes identified by the [XPath 1.0] path "//xsd:schema/xsd:annotation/xsd:appinfo/*".
#                             The value of the @roleURI attribute identifies the @xlink:role attribute value that is being defined.
#                             5.1.4 Defining custom arc role types - the arcroleType element
#                             The <arcroleType> element MUST be among the set of nodes identified by the [XPath 1.0] path "//xsd:schema/xsd:annotation/xsd:appinfo/*".
#                             The value of the @arcroleURI identifies the @xlink:arcrole attribute value that is being defined.

                            elif search_tagName == 'schema':
                                for annotation_ElementTree in schema_ElementTree.findall('annotation'):
                                    for appinfo_ElementTree in annotation_ElementTree.findall('appinfo'):
                                        
                                        roleType_Tags = ['roleType','arcroleType']
                                        for empty_Var, temp_tagName in enumerate(roleType_Tags):
                                            for temp_roleType_ElementTree in appinfo_ElementTree.findall(temp_tagName): #
                                                df_RoleTypes = df_RoleTypes.append(\
                                                    {'filepath':CurrentPathName,\
                                                     'roletypeObj':HibachiXmlElement.Roletype(CurrentFileName, temp_roleType_ElementTree)}\
                                                    ,ignore_index=True
                                                )
                                                
                                        roleRef_Tags = ['roleRef', 'arcroleRef']
                                        for empty_Var, temp_tagName in enumerate(roleRef_Tags):
                                            for temp_roleRef_ElementTree in appinfo_ElementTree.findall(temp_tagName): #
                                                df_TaxonomySchema = df_TaxonomySchema.append(\
                                                    {'filepath':CurrentPathName,\
                                                     'TaxonomySchemaObj':HibachiXmlElement.TaxonomySchema(CurrentFileName, schema_ElementTree)}\
                                                    ,ignore_index=True
                                                )
                                        
                else:
                    print('No root element')

            except:
                print ('Error in reading:', CurrentPathName, sys.exc_info()[0], sys.exc_info()[1])
    return df_TaxonomySchema, df_Linkbases, df_RoleTypes

# %%
# Run the function
df_Taxonomy, df_Linkbase, df_RoleType = readXSDinGeneralDTS(df_generalDTS=df_DTSPathes)
# Out:
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\common\\2013-08-31/identificationAndOrdering_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2013-08-31/jpcrp_cor_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2013-08-31/jpcrp_rt_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2015-03-31/jpcrp_cor_2015-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2015-03-31/jpcrp_rt_2015-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2015-03-31\\deprecated/jpcrp_dep_2015-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2016-02-29/jpcrp_cor_2016-02-29.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2016-02-29/jpcrp_rt_2016-02-29.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2016-02-29\\deprecated/jpcrp_dep_2016-02-29.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2017-02-28/jpcrp_cor_2017-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2017-02-28/jpcrp_rt_2017-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2017-02-28\\deprecated/jpcrp_dep_2017-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2018-02-28/jpcrp_cor_2018-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2018-02-28/jpcrp_rt_2018-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2018-02-28\\deprecated/jpcrp_dep_2018-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2019-02-28/jpcrp_cor_2019-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2019-02-28/jpcrp_rt_2019-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2019-02-28\\deprecated/jpcrp_dep_2019-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2019-11-01/jpcrp_cor_2019-11-01.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2019-11-01/jpcrp_rt_2019-11-01.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp\\2019-11-01\\deprecated/jpcrp_dep_2019-11-01.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp-esr\\2015-04-30/jpcrp-esr_cor_2015-04-30.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp-esr\\2015-04-30/jpcrp-esr_rt_2015-04-30.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp-esr\\2019-11-01/jpcrp-esr_cor_2019-11-01.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp-esr\\2019-11-01/jpcrp-esr_rt_2019-11-01.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp-sbr\\2013-08-31/jpcrp-sbr_cor_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpcrp-sbr\\2013-08-31/jpcrp-sbr_rt_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpctl\\2013-08-31/jpctl_cor_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpctl\\2013-08-31/jpctl_rt_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpdei\\2013-08-31/jpdei_cor_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpdei\\2013-08-31/jpdei_rt_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpigp\\2019-11-01/jpigp_cor_2019-11-01.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpigp\\2019-11-01/jpigp_rt_2019-11-01.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpigp\\2019-11-01\\deprecated/jpigp_dep_2019-11-01.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jplvh\\2013-08-31/jplvh_cor_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jplvh\\2013-08-31/jplvh_rt_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jplvh\\2014-07-31/jplvh_cor_2014-07-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jplvh\\2014-07-31/jplvh_rt_2014-07-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2013-08-31/jppfs_cor_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2013-08-31/jppfs_pe_2012.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2013-08-31/jppfs_rt_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2013-08-31\\deprecated/jppfs_dep_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2015-03-31/jppfs_cor_2015-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2015-03-31/jppfs_pe_2012.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2015-03-31/jppfs_rt_2015-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2015-03-31\\deprecated/jppfs_dep_2015-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2016-02-29/jppfs_cor_2016-02-29.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2016-02-29/jppfs_pe_2012.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2016-02-29/jppfs_rt_2016-02-29.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2016-02-29\\deprecated/jppfs_dep_2016-02-29.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2017-02-28/jppfs_cor_2017-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2017-02-28/jppfs_pe_2012.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2017-02-28/jppfs_rt_2017-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2017-02-28\\deprecated/jppfs_dep_2017-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2018-02-28/jppfs_cor_2018-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2018-02-28/jppfs_pe_2012.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2018-02-28/jppfs_rt_2018-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2018-02-28\\deprecated/jppfs_dep_2018-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2019-02-28/jppfs_cor_2019-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2019-02-28/jppfs_pe_2012.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2019-02-28/jppfs_rt_2019-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2019-02-28\\deprecated/jppfs_dep_2019-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2019-11-01/jppfs_cor_2019-11-01.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2019-11-01/jppfs_pe_2012.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2019-11-01/jppfs_rt_2019-11-01.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jppfs\\2019-11-01\\deprecated/jppfs_dep_2019-11-01.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps\\2013-08-31/jpsps_cor_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps\\2013-08-31/jpsps_rt_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps\\2015-03-31/jpsps_cor_2015-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps\\2015-03-31/jpsps_rt_2015-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps\\2017-02-28/jpsps_cor_2017-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps\\2017-02-28/jpsps_rt_2017-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps\\2018-02-28/jpsps_cor_2018-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps\\2018-02-28/jpsps_rt_2018-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps\\2019-02-28/jpsps_cor_2019-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps\\2019-02-28/jpsps_rt_2019-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps\\2019-02-28\\deprecated/jpsps_dep_2019-02-28.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps-esr\\2014-03-31/jpsps-esr_cor_2014-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps-esr\\2014-03-31/jpsps-esr_rt_2014-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps-esr\\2019-11-01/jpsps-esr_cor_2019-11-01.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps-esr\\2019-11-01/jpsps-esr_rt_2019-11-01.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps-sbr\\2014-07-31/jpsps-sbr_cor_2014-07-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jpsps-sbr\\2014-07-31/jpsps-sbr_rt_2014-07-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoi\\2014-03-31/jptoi_cor_2014-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoi\\2014-03-31/jptoi_rt_2014-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoi\\2014-07-31/jptoi_cor_2014-07-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoi\\2014-07-31/jptoi_rt_2014-07-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoo-pst\\2013-08-31/jptoo-pst_cor_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoo-pst\\2013-08-31/jptoo-pst_rt_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoo-toa\\2013-08-31/jptoo-toa_cor_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoo-toa\\2013-08-31/jptoo-toa_rt_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoo-ton\\2014-03-31/jptoo-ton_cor_2014-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoo-ton\\2014-03-31/jptoo-ton_rt_2014-03-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoo-tor\\2013-08-31/jptoo-tor_cor_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoo-tor\\2013-08-31/jptoo-tor_rt_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoo-wto\\2013-08-31/jptoo-wto_cor_2013-08-31.xsd'
# No root element
# Error when parsing <class 'FileNotFoundError'> [Errno 2] No such file or directory: 'EdinetGeneraltaxonomy\\jptoo-wto\\2013-08-31/jptoo-wto_rt_2013-08-31.xsd'
# No root element

# %%
# Unfold the Taxonomy Schema instace to Series and put it into dataframe
# Concate the unfolded dataframe to the original dataframe
#df_Taxonomy = pd.concat([df_Taxonomy.drop(['TaxonomySchemaObj'], axis=1), df_TaxonomySchema], axis=1)
df_Taxonomy = df_Taxonomy['TaxonomySchemaObj'].apply(lambda x: pd.Series(x.__dict__))
df_RoleType = df_RoleType['roletypeObj'].apply(lambda x: pd.Series(x.__dict__))

# %%
# Save the dataframe containing general DTS to PostgreSQL

# Connect to PostgreSQL
from sqlalchemy import create_engine
from config import config

try:
    params = config()
    engine = create_engine('postgresql://{user}:{password}@{host}:{port}/{database}'.format(**params))

    # Save the dataframe to PostgreSQL (make sure to type table names in lower cases)
    df_Taxonomy.to_sql('taxonomyschema_generaldts', con=engine, if_exists='replace', index=False)
    #df_RoleType.to_sql('roletype_generaldts', con=engine, if_exists='replace', index=False)
except:
    print ('Error:', sys.exc_info()[0], sys.exc_info()[1])
# Out:
# Error: <class 'sqlalchemy.exc.ProgrammingError'> (psycopg2.ProgrammingError) can't adapt type 'dict'
# [SQL: INSERT INTO roletype_generaldts (tag, id, type, role, arcrole, base, originalpath, fragment_id, href_type, searchablepath, "roleURI", "arcroleURI", "cyclesAllowed", "childElementDict") VALUES (%(tag)s, %(id)s, %(type)s, %(role)s, %(arcrole)s, %(base)s, %(originalpath)s, %(fragment_id)s, %(href_type)s, %(searchablepath)s, %(roleURI)s, %(arcroleURI)s, %(cyclesAllowed)s, %(childElementDict)s)]
# [parameters: ({'tag': 'roleType', 'id': 'rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo2SecuritiesRegistrationStatement', 'type': None, 'role': None, 'arcrole': None, 'base': None, 'originalpath': None, 'fragment_id': None, 'href_type': 'No href', 'searchablepath': None, 'roleURI': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo2SecuritiesRegistrationStatement', 'arcroleURI': None, 'cyclesAllowed': None, 'childElementDict': {'definition': '企業内容等の開示に関する内閣府令 第二号様式 有価証券届出書', 'usedOn': None}}, {'tag': 'roleType', 'id': 'rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo22SecuritiesRegistrationStatement', 'type': None, 'role': None, 'arcrole': None, 'base': None, 'originalpath': None, 'fragment_id': None, 'href_type': 'No href', 'searchablepath': None, 'roleURI': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo22SecuritiesRegistrationStatement', 'arcroleURI': None, 'cyclesAllowed': None, 'childElementDict': {'definition': '企業内容等の開示に関する内閣府令 第二号の二様式 有価証券届出書', 'usedOn': None}}, {'tag': 'roleType', 'id': 'rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo23SecuritiesRegistrationStatement', 'type': None, 'role': None, 'arcrole': None, 'base': None, 'originalpath': None, 'fragment_id': None, 'href_type': 'No href', 'searchablepath': None, 'roleURI': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo23SecuritiesRegistrationStatement', 'arcroleURI': None, 'cyclesAllowed': None, 'childElementDict': {'definition': '企業内容等の開示に関する内閣府令 第二号の三様式 有価証券届出書', 'usedOn': None}}, {'tag': 'roleType', 'id': 'rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo24SecuritiesRegistrationStatement', 'type': None, 'role': None, 'arcrole': None, 'base': None, 'originalpath': None, 'fragment_id': None, 'href_type': 'No href', 'searchablepath': None, 'roleURI': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo24SecuritiesRegistrationStatement', 'arcroleURI': None, 'cyclesAllowed': None, 'childElementDict': {'definition': '企業内容等の開示に関する内閣府令 第二号の四様式 有価証券届出書', 'usedOn': None}}, {'tag': 'roleType', 'id': 'rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo25SecuritiesRegistrationStatement', 'type': None, 'role': None, 'arcrole': None, 'base': None, 'originalpath': None, 'fragment_id': None, 'href_type': 'No href', 'searchablepath': None, 'roleURI': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo25SecuritiesRegistrationStatement', 'arcroleURI': None, 'cyclesAllowed': None, 'childElementDict': {'definition': '企業内容等の開示に関する内閣府令 第二号の五様式 有価証券届出書', 'usedOn': None}}, {'tag': 'roleType', 'id': 'rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo26SecuritiesRegistrationStatement', 'type': None, 'role': None, 'arcrole': None, 'base': None, 'originalpath': None, 'fragment_id': None, 'href_type': 'No href', 'searchablepath': None, 'roleURI': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo26SecuritiesRegistrationStatement', 'arcroleURI': None, 'cyclesAllowed': None, 'childElementDict': {'definition': '企業内容等の開示に関する内閣府令 第二号の六様式 有価証券届出書', 'usedOn': None}}, {'tag': 'roleType', 'id': 'rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo27SecuritiesRegistrationStatement', 'type': None, 'role': None, 'arcrole': None, 'base': None, 'originalpath': None, 'fragment_id': None, 'href_type': 'No href', 'searchablepath': None, 'roleURI': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_std_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo27SecuritiesRegistrationStatement', 'arcroleURI': None, 'cycles ...
# (Background on this error at: http://sqlalche.me/e/13/f405)
